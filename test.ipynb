# %%
import os
import json
# read json files from a directory
data = []
path='./contracts-extra/'
for root,subFolder,filename in os.walk(path):
    for filen in filename:

        print(filen)
        with open(root+"/" + filen ,encoding='UTF-8') as f:
            print(len(data)+1)
            try:
                data.append(json.load(f))
            except:
                print('Error reading file')
                continue


# write list as csv file
# with open('addresses.csv', 'w') as f:
#     f.write('\n'.join(data))
res=[]
for i in data:
    # print(i)
    try:
        print(i['result'][0]['CompilerVersion'][:4])
        if i['result'][0]['CompilerVersion'][:4]!="v0.4":
            continue
        with open('./contracts-extra-extracted-v4/'+i['result'][0]['ContractName']+'.sol','w') as f:
            try:
                f.write(i['result'][0]['SourceCode'])
            except:
                print('Error reading file')
    except:
        # print(i)
        print(0)
    # res+=[[i['ContractName'],i['SourceCode']]]
# Out:
# DaiBackstopSyndicateEnlisterV1.sol
# 1
# Error reading file
# DaiBackstopSyndicateEnlisterV3.sol
# 1
# Error reading file
# DaiBackstopSyndicateV0.sol
# 1
# Error reading file
# DaiBackstopSyndicateV2.sol
# 1
# Error reading file
# DaiBackstopSyndicateV3.sol
# 1
# Error reading file
# TokenFactoryProxy.sol
# 1
# Error reading file
# 0x000000000019fff0e5b945e90ee1e606aa22c6c2.json
# 1
# 0x000000000092c287eb63e8c2c30b4a74787054f8.json
# 2
# 0x00000000175121e210e2a36f3cd9468bad41e660.json
# 3
# 0x00000000357646e36fe575885bb3e1a0772e64cc.json
# 4
# 0x0000000041087b924ee4de5567c85adcc4e00098.json
# 5
# 0x000000007f8ea40a849c00ef59b8690bc56d7d98.json
# 6
# 0x000000008eb3d0a15fb54e6c00464ab8f55b5f8c.json
# 7
# 0x00000000938f41360a846490409500d08919856c.json
# 8
# 0x00000000c8bdb2c7db23eccf7500efc3c2ab7b99.json
# 9
# 0x000009b11c29428832d039d0af4b2e2b25a02969.json
# 10
# 0x000d2d31815990fca6f69dfd978c4d4a56b2ed6b.json
# 11
# 0x0017a04a2e182376235530d501bc3fbe7ca07a5b.json
# 12
# 0x002c97933d0976dbcf51c0e8f8a3e64d8fd9d296.json
# 13
# 0x003dbccacd2ea95ce8f958a71d28ce660ce36879.json
# 14
# 0x0087e970dfd8303bccf3e2b7bfbb2a6c8b46d43f.json
# 15
# 0x009d11fe629ac307c297fed504e653e6f001cc87.json
# 16
# 0x00b7ed96a23cbc777b54b24ca1e6d6a054768cda.json
# 17
# 0x00e07c2c78695418d84485eee1ed293a3867d9c3.json
# 18
# 0x010c282118aa76174ce5952572ba715cf60a0c9b.json
# 19
# 0x0158d521bb6da3afa7600c4cf436a4f526421d66.json
# 20
# 0x0174a4c115f214cd42a6b90a16b97da36441c4e6.json
# 21
# 0x01c0987e88f778df6640787226bc96354e1a9766.json
# 22
# 0x01eee9f6dad971da52f3d0400431692b29573da3.json
# 23
# 0x01fec9f6a261b9e1a7b936e95ccaeea51a023750.json
# 24
# 0x0213f0e6270024e759f504f5cc2b1fbbcc1c7f35.json
# 25
# 0x02b1669bc9ee893edaff3cadfd326a294d643f99.json
# 26
# 1565
# 0xfefc8ffb329b6dfe755d24f86a19f604cebdf3ce.json
# 1566
# 0xfeffef186885b00fb5493ff53648e8f76ba933fc.json
# 1567
# 0xff97c79d207fc3d7a51531d0fa93581cf8e0105d.json
# 1568
# 0xffb0e0aa425c3bb62c2e9e66a3e9325e40a472da.json
# 1569
# 0xffeba71dba37a6f9af18c3ae11b3a62a05cda280.json
# 1570
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# 0
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.4
# v0.5
# v0.6
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# vype
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.6
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.6
# 0
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# Error reading file
# v0.6
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.6
# v0.6
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# 0
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.6
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.6
# v0.6
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.6
# v0.4
# v0.4
# v0.6
# v0.4
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.6
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.6
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.6
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.4
# v0.6
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.4
# v0.6
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.6
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.4
# Error reading file
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# 0
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.6
# v0.5
# v0.4
# v0.6
# v0.4
# v0.6
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.4
# v0.6
# v0.4
# v0.4
# v0.6
# v0.4
# v0.6
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# 0
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.6
# v0.6
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.6
# v0.4
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.6
# v0.5
# v0.6
# v0.4
# v0.5
# v0.6
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.6
# v0.4
# v0.5
# v0.4
# v0.5
# v0.6
# v0.6
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.4
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# 0
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.6
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.4
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.6
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.4
# v0.4
# v0.6
# v0.4
# v0.6
# v0.4
# v0.5
# v0.6
# v0.4
# v0.6
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# 0
# v0.6
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.6
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# Error reading file
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.4
# v0.5
# v0.6
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# v0.4
# Error reading file
# v0.5
# v0.6
# v0.5
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.6
# v0.4
# v0.6
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.6
# v0.5
# v0.5
# v0.6
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.4
# v0.4
# v0.4
# v0.4
# v0.5
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.4
# v0.5
# v0.4
# v0.6
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.5
# v0.5
# v0.4
# v0.5
# v0.6
# v0.5
# v0.4
# v0.5
# v0.4
# v0.4
# v0.5
# v0.4
# Error reading file
# v0.4
# v0.5
# v0.4
# v0.5
# v0.6
# v0.4
# v0.5
# v0.5
# v0.4
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# v0.5
# 0
# v0.4
# vype

# %%
# scrape data from etherscan
import requests
import bs4

base_address='https://ethervm.io/decompile/'
# read csv file
with open('addresses.csv', 'r') as f:
    addresses = f.read().split('\n')

# get data from ethervm
data = []
for address in addresses[:1]:
    url = base_address + address
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    # get contract source code
    print(soup)
    source = soup.find('code')
    print(source)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="//static.ethervm.io/css/fontawesome/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="//static.ethervm.io/css/bootstrap/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="//static.ethervm.io/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script src="https://code.jquery.com/jquery-3.2.1.slim.min.js"></script>
# <script defer="" src="//static.ethervm.io/js/site.js"></script>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/styles/vs2015.min.css" rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/highlight.min.js"></script>
# <title>Online Solidity Decompiler</title>
# <meta content="Online Solidity Decompiler" property="og:site_name">
# <meta content="0x007d42b9192b8c087b0d3e6ef73aae48e74b41c1" property="og:title"/>
# <meta content="//static.ethervm.io/img/og_thumb.png" property="og:image"/>
# <meta content="https://ethervm.io/decompile/0x007d42b9192b8C087b0D3E6ef73AAE48E74b41c1" property="og:url"/>
# <meta content="website" property="og:type"/>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
# 			(adsbygoogle = window.adsbygoogle || []).push({
# 				google_ad_client: "ca-pub-2505358888082587",
# 				enable_page_level_ads: true
# 			});
# 		</script>
# </meta></head>
# <body>
# <div class="navbar navbar-expand-md navbar-dark bg-dark fixed-top navbar-background">
# <a class="navbar-brand" href="/" style="padding-top: 0; padding-bottom: 0">
# <div style="width: 1.7em">
# <div style="text-align: center; height: 100%">
# <img src="//static.ethervm.io/img/ethereum.svg" style="height: 1.5em"/>
# </div>
# <div style="font-size: 0.4em; text-align: center; line-height: 1.5; font-family: Roboto; font-weight: 100; letter-spacing: 0.15em">
# 						011010
# 					</div>
# </div>
# </a>
# <button aria-controls="navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="navbar-collapse collapse" id="navbar">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item"><a class="nav-link" href="/">Reference</a></li>
# <li class="nav-item"><a class="nav-link" href="/decompile">Decompile</a></li>
# </ul>
# <ul class="navbar-nav">
# </ul>
# </div>
# </div>
# <div class="container">
# <div data-server-rendered="true"><h1>Online Solidity Decompiler</h1> <a href="/decompile">« Decompile another contract</a><br/> <div><div><a class="anchor"></a> <h2>Address<a class="link fa fa-link" href="#undefined" style="margin-left: 0.4em; font-size: 0.4em"></a></h2></div> <tt>0x007d42b9192b8c087b0d3e6ef73aae48e74b41c1</tt> <small>[<a href="https://etherscan.io/address/0x007d42b9192b8c087b0d3e6ef73aae48e74b41c1">etherscan.io<span class="fa fa-external-link"></span></a><!-- --><!-- --><!-- --><!-- --><!-- --> | <a href="https://etherchain.org/account/0x007d42b9192b8c087b0d3e6ef73aae48e74b41c1">etherchain.org<span class="fa fa-external-link"></span></a>]</small> <!-- --></div> <div><a class="anchor" name="methods"></a> <h2>Public Methods<a class="link fa fa-link" href="#methods" style="margin-left: 0.4em; font-size: 0.4em"></a></h2></div> <small style="color: gray"><i>Method names cached from <a href="https://www.4byte.directory">4byte.directory<span class="fa fa-external-link"></span></a>.</i><br/></small> <div><a href="#dispatch_1097e579"><tt>0x1097e579</tt></a> <tt>Enter()</tt><br/></div><div><a href="#dispatch_112c7075"><tt>0x112c7075</tt></a> <tt>ManualDeposit()</tt><br/></div><div><a href="#dispatch_3edd90e7"><tt>0x3edd90e7</tt></a> <tt>NewOwner(address)</tt><br/></div><div><a href="#dispatch_3feb5f2b"><tt>0x3feb5f2b</tt></a> <tt>investors(uint256)</tt><br/></div><div><a href="#dispatch_476e04c7"><tt>0x476e04c7</tt></a> <tt>NewMessage(string)</tt><br/></div><div><a href="#dispatch_4cd11943"><tt>0x4cd11943</tt></a> <tt>NewManualInvestor(address,uint256)</tt><br/></div><div><a href="#dispatch_6b1781b6"><tt>0x6b1781b6</tt></a> <tt>Emergency()</tt><br/></div><div><a href="#dispatch_6c3772fd"><tt>0x6c3772fd</tt></a> <tt>totalpaidout()</tt><br/></div><div><a href="#dispatch_8da5cb5b"><tt>0x8da5cb5b</tt></a> <tt>owner()</tt><br/></div><div><a href="#dispatch_9522ca89"><tt>0x9522ca89</tt></a> <tt>Message_To_Investors()</tt><br/></div><div><a href="#dispatch_9af1d35a"><tt>0x9af1d35a</tt></a> <tt>fees()</tt><br/></div><div><a href="#dispatch_a6b165ee"><tt>0xa6b165ee</tt></a> <tt>total_investors()</tt><br/></div><div><a href="#dispatch_b69ef8a8"><tt>0xb69ef8a8</tt></a> <tt>balance()</tt><br/></div><div><a href="#dispatch_bda393d3"><tt>0xbda393d3</tt></a> <tt>totaldividends()</tt><br/></div><div><a href="#dispatch_d7315d60"><tt>0xd7315d60</tt></a> <tt>totaldeposited()</tt><br/></div> <!-- --> <div><a class="anchor" name="internal"></a> <h2>Internal Methods<a class="link fa fa-link" href="#internal" style="margin-left: 0.4em; font-size: 0.4em"></a></h2></div> <div><tt><a href="#func_Enter">Enter</a>()
# 			<!-- --></tt><br/></div><div><tt><a href="#func_func_01F0">func_01F0</a>()
# 			<!-- --></tt><br/></div><div><tt><a href="#func_investors">investors</a>(arg1, arg3)
# 			<span>returns (r0, r1, r2)</span></tt><br/></div><div><tt><a href="#func_func_04A2">func_04A2</a>(arg0, arg1)
# 			<!-- --></tt><br/></div><div><tt><a href="#func_func_0501">func_0501</a>()
# 			<!-- --></tt><br/></div><div><tt><a href="#func_func_0679">func_0679</a>()
# 			<!-- --></tt><br/></div><div><tt><a href="#func_func_076C">func_076C</a>(arg0, arg1, arg2, arg3, arg4)
# 			<!-- --></tt><br/></div><div><tt><a href="#func_func_0835">func_0835</a>(arg0, arg1)
# 			<span>returns (r0)</span></tt><br/></div><div><tt><a href="#func_func_08EC">func_08EC</a>(arg0, arg1)
# 			<span>returns (r0)</span></tt><br/></div><div><tt><a href="#func_func_0900">func_0900</a>(arg0, arg1)
# 			<span>returns (r0)</span></tt><br/></div><div><tt><a href="#func_func_0B7E">func_0B7E</a>(arg0)
# 			<!-- --></tt><br/></div><div><tt><a href="#func_func_0BBD">func_0BBD</a>(arg0, arg1)
# 			<!-- --></tt><br/></div> <!-- --> <div><a class="anchor" name="decompilation"></a> <h2>Decompilation<a class="link fa fa-link" href="#decompilation" style="margin-left: 0.4em; font-size: 0.4em"></a></h2></div> <!-- --> <!-- --> <!-- --> <div class="code javascript" style="border: 1px solid gray; padding: 0.5em; white-space: pre; font-family: monospace; line-height: 1.2">contract Contract {
# <a class="anchor" name="func_main"></a>    function main() {
#         memory[0x40:0x60] = 0x60;
#
#         if (!msg.data.length) {
#         label_00B9:
#             var var0 = 0x0677;
#             var var1 = 0x0679;
#             <a class="hljs-name" href="#func_Enter">Enter</a>();
#             <a class="hljs-name" href="#func_func_0679">func_0679</a>();
#             stop();
#         } else {
#         label_000B:
#             var0 = msg.data[0x00:0x20] / 0x02 ** 0xe0;
#
# <a class="anchor" name="dispatch_1097e579"></a>            if (var0 == 0x1097e579) {
#                 // Dispatch table entry for <a class="hljs-name" href="#func_Enter">Enter</a>()
#                 var1 = 0x0677;
#                 <a class="hljs-name" href="#func_Enter">Enter</a>();
#                 stop();
# <a class="anchor" name="dispatch_112c7075"></a>            } else if (var0 == 0x112c7075) {
#                 // Dispatch table entry for ManualDeposit()
#                 var1 = 0x0677;
#                 var temp0 = 0x02 ** 0xa0 - 0x01;
#
#                 if (temp0 &amp; msg.sender != temp0 &amp; storage[0x08]) {
#                     <a class="hljs-name" href="#func_func_0679">func_0679</a>();
#                     stop();
#                 } else {
#                     <a class="hljs-name" href="#func_func_01F0">func_01F0</a>();
#                     stop();
#                 }
# <a class="anchor" name="dispatch_3edd90e7"></a>            } else if (var0 == 0x3edd90e7) {
#                 // Dispatch table entry for NewOwner(address)
#                 var1 = 0x0677;
#                 var var2 = msg.data[0x04:0x24];
#                 var temp1 = 0x02 ** 0xa0 - 0x01;
#
#                 if (temp1 &amp; msg.sender != temp1 &amp; storage[0x08]) {
#                     <a class="hljs-name" href="#func_func_0B7E">func_0B7E</a>(var2);
#                     stop();
#                 } else {
#                     storage[0x08] = var2 | (storage[0x08] &amp; ~(0x02 ** 0xa0 - 0x01));
#                     var temp2 = memory[0x40:0x60];
#                     memory[0x40:0x60] = temp2 + 0x40;
#                     memory[temp2:temp2 + 0x20] = 0x1f;
#                     var temp3 = temp2 + 0x20;
#                     memory[temp3:temp3 + 0x20] = 0x54686520636f6e7472616374206861732061206e6577206d616e616765722100;
#                     var temp4 = storage[0x07];
#                     memory[0x00:0x20] = 0x07;
#                     var var3 = 0x07;
#                     var temp5 = memory[0x00:0x20];
#                     memory[0x00:0x20] = code[0x0d54:0x0d74];
#                     var temp6 = memory[0x00:0x20];
#                     memory[0x00:0x20] = temp5;
#                     var var6 = temp6;
#                     storage[var3] = (memory[temp3:temp3 + 0x20] &amp; ~0xff) | 0x1f + 0x1f;
#                     var var4 = 0x0b7b;
#                     var var5 = var6 + ((temp4 &amp; !(temp4 &amp; 0x01) * 0x0100 + ~0x00) / 0x02 + 0x1f) / 0x20;
#                     var4 = <a class="hljs-name" href="#func_func_08EC">func_08EC</a>(var5, var6);
#
#                 label_0B7B:
#                     <a class="hljs-name" href="#func_func_0B7E">func_0B7E</a>(var2);
#                     // Error: Could not resolve method call return address!
#                 }
# <a class="anchor" name="dispatch_3feb5f2b"></a>            } else if (var0 == 0x3feb5f2b) {
#                 // Dispatch table entry for <a class="hljs-name" href="#func_investors">investors</a>(uint256)
#                 var1 = 0x067b;
#                 var2 = msg.data[0x04:0x24];
#                 var3 = 0x00;
#                 var4 = var2;
#
#                 if (var4 &gt;= storage[var3]) {
#                     memory[0x40:0x60] = var4;
#
#                     if (!msg.data.length) { goto label_00B9; }
#                     else { goto label_000B; }
#                 } else {
#                     var2, var3, var4 = <a class="hljs-name" href="#func_investors">investors</a>(var2, var3);
#                     var temp7 = memory[0x40:0x60];
#                     memory[temp7:temp7 + 0x20] = var2 &amp; 0x02 ** 0xa0 - 0x01;
#                     memory[temp7 + 0x20:temp7 + 0x20 + 0x20] = var3;
#                     memory[temp7 + 0x40:temp7 + 0x40 + 0x20] = var4;
#                     var temp8 = memory[0x40:0x60];
#                     return memory[temp8:temp8 + temp7 - temp8 + 0x60];
#                 }
# <a class="anchor" name="dispatch_476e04c7"></a>            } else if (var0 == 0x476e04c7) {
#                 // Dispatch table entry for NewMessage(string)
#                 var temp9 = memory[0x40:0x60];
#                 var temp10 = msg.data[0x04:0x24];
#                 var temp11 = msg.data[temp10 + 0x04:temp10 + 0x04 + 0x20];
#                 memory[0x40:0x60] = temp9 + (temp11 + 0x1f) / 0x20 * 0x20 + 0x20;
#                 memory[temp9:temp9 + 0x20] = temp11;
#                 var1 = 0x0677;
#                 memory[temp9 + 0x20:temp9 + 0x20 + temp11] = msg.data[temp10 + 0x24:temp10 + 0x24 + temp11];
#                 var2 = temp9;
#                 var temp12 = 0x02 ** 0xa0 - 0x01;
#
#                 if (temp12 &amp; msg.sender != temp12 &amp; storage[0x08]) {
#                     <a class="hljs-name" href="#func_func_0B7E">func_0B7E</a>(var2);
#                     stop();
#                 } else {
#                     var temp13 = var2;
#                     var3 = 0x07;
#                     var temp14 = memory[temp13:temp13 + 0x20];
#                     var5 = temp14;
#                     var temp15 = storage[var3];
#                     memory[0x00:0x20] = var3;
#                     var6 = keccak256(memory[0x00:0x20]);
#                     var4 = var6 + ((!(temp15 &amp; 0x01) * 0x0100 - 0x01 &amp; temp15) / 0x02 + 0x1f) / 0x20;
#                     var var7 = temp13 + 0x20;
#
#                     if (0x1f &lt; var5) {
#                         var temp16 = var5;
#                         storage[var3] = temp16 + temp16 + 0x01;
#
#                         if (!temp16) {
#                         label_0366:
#                             var temp17 = var4;
#                             var4 = 0x0b7b;
#                             var5 = temp17;
#                             var4 = <a class="hljs-name" href="#func_func_08EC">func_08EC</a>(var5, var6);
#                             goto label_0B7B;
#                         } else {
#                             var temp18 = var5;
#                             var temp19 = var7;
#                             var5 = temp19;
#                             var7 = var5 + temp18;
#
#                             if (var7 &lt;= var5) { goto label_0366; }
#
#                         label_0B9C:
#                             var temp20 = var5;
#                             var temp21 = var6;
#                             storage[temp21] = memory[temp20:temp20 + 0x20];
#                             var5 = temp20 + 0x20;
#                             var6 = temp21 + 0x01;
#                             var7 = var7;
#
#                             if (var7 &lt;= var5) { goto label_0366; }
#                             else { goto label_0B9C; }
#                         }
#                     } else {
#                         var temp22 = var5;
#                         storage[var3] = temp22 + temp22 | (memory[var7:var7 + 0x20] &amp; ~0xff);
#                         goto label_0366;
#                     }
#                 }
# <a class="anchor" name="dispatch_4cd11943"></a>            } else if (var0 == 0x4cd11943) {
#                 // Dispatch table entry for NewManualInvestor(address,uint256)
#                 var1 = 0x0677;
#                 var2 = msg.data[0x04:0x24];
#                 var3 = msg.data[0x24:0x44];
#                 var temp23 = 0x02 ** 0xa0 - 0x01;
#
#                 if (temp23 &amp; msg.sender != temp23 &amp; storage[0x08]) {
#                     <a class="hljs-name" href="#func_func_0BBD">func_0BBD</a>(var2, var3);
#                     stop();
#                 } else {
#                     <a class="hljs-name" href="#func_func_04A2">func_04A2</a>(var2, var3);
#                     stop();
#                 }
# <a class="anchor" name="dispatch_6b1781b6"></a>            } else if (var0 == 0x6b1781b6) {
#                 // Dispatch table entry for Emergency()
#                 var1 = 0x0677;
#                 var temp24 = 0x02 ** 0xa0 - 0x01;
#
#                 if (temp24 &amp; msg.sender != temp24 &amp; storage[0x08]) {
#                     <a class="hljs-name" href="#func_func_0679">func_0679</a>();
#                     stop();
#                 } else {
#                     <a class="hljs-name" href="#func_func_0501">func_0501</a>();
#                     stop();
#                 }
# <a class="anchor" name="dispatch_6c3772fd"></a>            } else if (var0 == 0x6c3772fd) {
#                 // Dispatch table entry for totalpaidout()
#                 var1 = 0x06a4;
#                 var2 = storage[0x05];
#
#             label_06A4:
#                 var temp25 = memory[0x40:0x60];
#                 memory[temp25:temp25 + 0x20] = var2;
#                 var temp26 = memory[0x40:0x60];
#                 return memory[temp26:temp26 + temp25 - temp26 + 0x20];
# <a class="anchor" name="dispatch_8da5cb5b"></a>            } else if (var0 == 0x8da5cb5b) {
#                 // Dispatch table entry for owner()
#                 var1 = 0x06b6;
#                 var2 = storage[0x08] &amp; 0x02 ** 0xa0 - 0x01;
#                 var temp27 = memory[0x40:0x60];
#                 memory[temp27:temp27 + 0x20] = var2 &amp; 0x02 ** 0xa0 - 0x01;
#                 var temp28 = memory[0x40:0x60];
#                 return memory[temp28:temp28 + temp27 - temp28 + 0x20];
# <a class="anchor" name="dispatch_9522ca89"></a>            } else if (var0 == 0x9522ca89) {
#                 // Dispatch table entry for Message_To_Investors()
#                 var temp29 = memory[0x40:0x60];
#                 var2 = temp29;
#                 var3 = 0x07;
#                 var temp30 = storage[var3];
#                 var temp31 = (temp30 &amp; !(temp30 &amp; 0x01) * 0x0100 + ~0x00) / 0x02;
#                 memory[0x40:0x60] = var2 + (temp31 + 0x1f) / 0x20 * 0x20 + 0x20;
#                 memory[var2:var2 + 0x20] = temp31;
#                 var1 = 0x06d3;
#                 var4 = temp31;
#                 var5 = var2 + 0x20;
#                 var6 = var3;
#                 var7 = var4;
#
#                 if (!var7) {
#                     <a class="hljs-name" href="#func_func_076C">func_076C</a>(var3, var4, var5, var6, var7);
#                     var temp32 = memory[0x40:0x60];
#                     var3 = temp32;
#                     var4 = var3;
#                     var temp33 = var4 + 0x20;
#                     memory[var4:var4 + 0x20] = temp33 - var4;
#                     var temp34 = var2;
#                     memory[temp33:temp33 + 0x20] = memory[temp34:temp34 + 0x20];
#                     var temp35 = temp33 + 0x20;
#                     var temp36 = memory[temp34:temp34 + 0x20];
#                     memory[temp35:temp35 + temp36] = address(0x04).call.gas((temp36 + 0x1f) / 0x20 * 0x0f + 0x03)(memory[temp34 + 0x20:temp34 + 0x20 + temp36]);
#                     var5 = temp36 + temp35;
#                     var6 = temp36 &amp; 0x1f;
#
#                     if (!var6) {
#                         var temp37 = memory[0x40:0x60];
#                         return memory[temp37:temp37 + var5 - temp37];
#                     } else {
#                         var temp38 = var6;
#                         var temp39 = var5 - temp38;
#                         memory[temp39:temp39 + 0x20] = ~(0x0100 ** (0x20 - temp38) - 0x01) &amp; memory[temp39:temp39 + 0x20];
#                         var temp40 = memory[0x40:0x60];
#                         return memory[temp40:temp40 + (temp39 + 0x20) - temp40];
#                     }
#                 } else if (0x1f &lt; var7) {
#                     var temp41 = var5;
#                     var temp42 = temp41 + var7;
#                     var5 = temp42;
#                     memory[0x00:0x20] = var6;
#                     var temp43 = keccak256(memory[0x00:0x20]);
#                     memory[temp41:temp41 + 0x20] = storage[temp43];
#                     var6 = temp43 + 0x01;
#                     var7 = temp41 + 0x20;
#
#                     if (var5 &lt;= var7) { goto label_0763; }
#
#                 label_074F:
#                     var temp44 = var6;
#                     var temp45 = var7;
#                     memory[temp45:temp45 + 0x20] = storage[temp44];
#                     var6 = temp44 + 0x01;
#                     var7 = temp45 + 0x20;
#
#                     if (var5 &gt; var7) { goto label_074F; }
#
#                 label_0763:
#                     var temp46 = var5;
#                     var temp47 = temp46 + (var7 - temp46 &amp; 0x1f);
#                     var7 = temp46;
#                     var5 = temp47;
#                     <a class="hljs-name" href="#func_func_076C">func_076C</a>(var3, var4, var5, var6, var7);
#                     // Error: Could not resolve method call return address!
#                 } else {
#                     var temp48 = var5;
#                     memory[temp48:temp48 + 0x20] = storage[var6] / 0x0100 * 0x0100;
#                     var5 = temp48 + 0x20;
#                     var7 = var7;
#                     <a class="hljs-name" href="#func_func_076C">func_076C</a>(var3, var4, var5, var6, var7);
#                     // Error: Could not resolve method call return address!
#                 }
# <a class="anchor" name="dispatch_9af1d35a"></a>            } else if (var0 == 0x9af1d35a) {
#                 // Dispatch table entry for fees()
#                 var1 = 0x06a4;
#                 var2 = storage[0x02];
#                 goto label_06A4;
# <a class="anchor" name="dispatch_a6b165ee"></a>            } else if (var0 == 0xa6b165ee) {
#                 // Dispatch table entry for total_investors()
#                 var1 = 0x06a4;
#                 var2 = storage[0x01];
#                 goto label_06A4;
# <a class="anchor" name="dispatch_b69ef8a8"></a>            } else if (var0 == 0xb69ef8a8) {
#                 // Dispatch table entry for balance()
#                 var1 = 0x06a4;
#                 var2 = storage[0x03];
#                 goto label_06A4;
# <a class="anchor" name="dispatch_bda393d3"></a>            } else if (var0 == 0xbda393d3) {
#                 // Dispatch table entry for totaldividends()
#                 var1 = 0x06a4;
#                 var2 = storage[0x06];
#                 goto label_06A4;
# <a class="anchor" name="dispatch_d7315d60"></a>            } else if (var0 == 0xd7315d60) {
#                 // Dispatch table entry for totaldeposited()
#                 var1 = 0x06a4;
#                 var2 = storage[0x04];
#                 goto label_06A4;
#             } else { goto label_00B9; }
#         }
#     }
#
# <a class="anchor" name="func_Enter"></a>    function Enter() {
#         var var0 = 0x00;
#         var var1 = 0x00;
#         var var2 = 0x00;
#         var var3 = 0x00;
#         var var4 = 0x00;
#         var var5 = 0x00;
#         var var6 = 0x00;
#         var var7 = 0x00;
#
#         if (msg.value &gt;= 0x1bc16d674ec80000) {
#             var temp0 = msg.value;
#             var temp1 = temp0 / 0x64;
#             storage[0x02] = temp1;
#             storage[0x04] = temp0 + storage[0x04];
#             storage[0x03] = temp0 - temp1 + storage[0x03];
#             var3 = temp0 - temp1;
#             var4 = 0x00;
#             var6 = var4;
#
#             if (var6 &gt;= storage[0x00]) {
#             label_07EC:
#
#                 if (var4 != 0x00) {
#                     var var8 = var3;
#                     var var9 = 0x00;
#                     var var10 = var5;
#
#                     if (var10 &gt;= storage[var9]) {
#                     label_0002:
#                         memory[0x40:0x60] = var10;
#
#                         if (!msg.data.length) {
#                         label_00B9:
#                             var10 = 0x0677;
#                             var var11 = 0x0679;
#                             <a class="hljs-name" href="#func_Enter">Enter</a>();
#                             <a class="hljs-name" href="#func_func_0679">func_0679</a>();
#                             stop();
#                         } else {
#                             var10 = msg.data[0x00:0x20] / 0x02 ** 0xe0;
#
#                             if (var10 == 0x1097e579) {
#                                 var11 = 0x0677;
#                                 <a class="hljs-name" href="#func_Enter">Enter</a>();
#                                 stop();
#                             } else if (var10 == 0x112c7075) {
#                                 var11 = 0x0677;
#                                 var temp2 = 0x02 ** 0xa0 - 0x01;
#
#                                 if (temp2 &amp; msg.sender != temp2 &amp; storage[0x08]) {
#                                     <a class="hljs-name" href="#func_func_0679">func_0679</a>();
#                                     stop();
#                                 } else {
#                                     <a class="hljs-name" href="#func_func_01F0">func_01F0</a>();
#                                     stop();
#                                 }
#                             } else if (var10 == 0x3edd90e7) {
#                                 var11 = 0x0677;
#                                 var var12 = msg.data[0x04:0x24];
#                                 var temp3 = 0x02 ** 0xa0 - 0x01;
#
#                                 if (temp3 &amp; msg.sender != temp3 &amp; storage[0x08]) {
#                                     <a class="hljs-name" href="#func_func_0B7E">func_0B7E</a>(var12);
#                                     stop();
#                                 } else {
#                                     storage[0x08] = var12 | (storage[0x08] &amp; ~(0x02 ** 0xa0 - 0x01));
#                                     var temp4 = memory[0x40:0x60];
#                                     memory[0x40:0x60] = temp4 + 0x40;
#                                     memory[temp4:temp4 + 0x20] = 0x1f;
#                                     var temp5 = temp4 + 0x20;
#                                     memory[temp5:temp5 + 0x20] = 0x54686520636f6e7472616374206861732061206e6577206d616e616765722100;
#                                     var temp6 = storage[0x07];
#                                     memory[0x00:0x20] = 0x07;
#                                     var var13 = 0x07;
#                                     var temp7 = memory[0x00:0x20];
#                                     memory[0x00:0x20] = code[0x0d54:0x0d74];
#                                     var temp8 = memory[0x00:0x20];
#                                     memory[0x00:0x20] = temp7;
#                                     var var16 = temp8;
#                                     storage[var13] = (memory[temp5:temp5 + 0x20] &amp; ~0xff) | 0x1f + 0x1f;
#                                     var var14 = 0x0b7b;
#                                     var var15 = var16 + ((temp6 &amp; !(temp6 &amp; 0x01) * 0x0100 + ~0x00) / 0x02 + 0x1f) / 0x20;
#                                     var14 = <a class="hljs-name" href="#func_func_08EC">func_08EC</a>(var15, var16);
#
#                                 label_0B7B:
#                                     <a class="hljs-name" href="#func_func_0B7E">func_0B7E</a>(var12);
#                                     // Error: Could not resolve method call return address!
#                                 }
#                             } else if (var10 == 0x3feb5f2b) {
#                                 var11 = 0x067b;
#                                 var12 = msg.data[0x04:0x24];
#                                 var13 = 0x00;
#                                 var14 = var12;
#
#                                 if (var14 &gt;= storage[var13]) { goto label_0002; }
#
#                                 var12, var13, var14 = <a class="hljs-name" href="#func_investors">investors</a>(var12, var13);
#                                 var temp9 = memory[0x40:0x60];
#                                 memory[temp9:temp9 + 0x20] = var12 &amp; 0x02 ** 0xa0 - 0x01;
#                                 memory[temp9 + 0x20:temp9 + 0x20 + 0x20] = var13;
#                                 memory[temp9 + 0x40:temp9 + 0x40 + 0x20] = var14;
#                                 var temp10 = memory[0x40:0x60];
#                                 return memory[temp10:temp10 + temp9 - temp10 + 0x60];
#                             } else if (var10 == 0x476e04c7) {
#                                 var temp11 = memory[0x40:0x60];
#                                 var temp12 = msg.data[0x04:0x24];
#                                 var temp13 = msg.data[temp12 + 0x04:temp12 + 0x04 + 0x20];
#                                 memory[0x40:0x60] = temp11 + (temp13 + 0x1f) / 0x20 * 0x20 + 0x20;
#                                 memory[temp11:temp11 + 0x20] = temp13;
#                                 var11 = 0x0677;
#                                 memory[temp11 + 0x20:temp11 + 0x20 + temp13] = msg.data[temp12 + 0x24:temp12 + 0x24 + temp13];
#                                 var12 = temp11;
#                                 var temp14 = 0x02 ** 0xa0 - 0x01;
#
#                                 if (temp14 &amp; msg.sender != temp14 &amp; storage[0x08]) {
#                                     <a class="hljs-name" href="#func_func_0B7E">func_0B7E</a>(var12);
#                                     stop();
#                                 } else {
#                                     var temp15 = var12;
#                                     var13 = 0x07;
#                                     var temp16 = memory[temp15:temp15 + 0x20];
#                                     var15 = temp16;
#                                     var temp17 = storage[var13];
#                                     memory[0x00:0x20] = var13;
#                                     var16 = keccak256(memory[0x00:0x20]);
#                                     var14 = var16 + ((!(temp17 &amp; 0x01) * 0x0100 - 0x01 &amp; temp17) / 0x02 + 0x1f) / 0x20;
#                                     var var17 = temp15 + 0x20;
#
#                                     if (0x1f &lt; var15) {
#                                         var temp18 = var15;
#                                         storage[var13] = temp18 + temp18 + 0x01;
#
#                                         if (!temp18) {
#                                         label_0366:
#                                             var temp19 = var14;
#                                             var14 = 0x0b7b;
#                                             var15 = temp19;
#                                             var14 = <a class="hljs-name" href="#func_func_08EC">func_08EC</a>(var15, var16);
#                                             goto label_0B7B;
#                                         } else {
#                                             var temp20 = var15;
#                                             var temp21 = var17;
#                                             var15 = temp21;
#                                             var17 = var15 + temp20;
#
#                                             if (var17 &lt;= var15) { goto label_0366; }
#
#                                         label_0B9C:
#                                             var temp22 = var15;
#                                             var temp23 = var16;
#                                             storage[temp23] = memory[temp22:temp22 + 0x20];
#                                             var15 = temp22 + 0x20;
#                                             var16 = temp23 + 0x01;
#                                             var17 = var17;
#
#                                             if (var17 &lt;= var15) { goto label_0366; }
#                                             else { goto label_0B9C; }
#                                         }
#                                     } else {
#                                         var temp24 = var15;
#                                         storage[var13] = temp24 + temp24 | (memory[var17:var17 + 0x20] &amp; ~0xff);
#                                         goto label_0366;
#                                     }
#                                 }
#                             } else if (var10 == 0x4cd11943) {
#                                 var11 = 0x0677;
#                                 var12 = msg.data[0x04:0x24];
#                                 var13 = msg.data[0x24:0x44];
#                                 var temp25 = 0x02 ** 0xa0 - 0x01;
#
#                                 if (temp25 &amp; msg.sender != temp25 &amp; storage[0x08]) {
#                                     <a class="hljs-name" href="#func_func_0BBD">func_0BBD</a>(var12, var13);
#                                     stop();
#                                 } else {
#                                     <a class="hljs-name" href="#func_func_04A2">func_04A2</a>(var12, var13);
#                                     stop();
#                                 }
#                             } else if (var10 == 0x6b1781b6) {
#                                 var11 = 0x0677;
#                                 var temp26 = 0x02 ** 0xa0 - 0x01;
#
#                                 if (temp26 &amp; msg.sender != temp26 &amp; storage[0x08]) {
#                                     <a class="hljs-name" href="#func_func_0679">func_0679</a>();
#                                     stop();
#                                 } else {
#                                     <a class="hljs-name" href="#func_func_0501">func_0501</a>();
#                                     stop();
#                                 }
#                             } else if (var10 == 0x6c3772fd) {
#                                 var11 = 0x06a4;
#                                 var12 = storage[0x05];
#
#                             label_06A4:
#                                 var temp27 = memory[0x40:0x60];
#                                 memory[temp27:temp27 + 0x20] = var12;
#                                 var temp28 = memory[0x40:0x60];
#                                 return memory[temp28:temp28 + temp27 - temp28 + 0x20];
#                             } else if (var10 == 0x8da5cb5b) {
#                                 var11 = 0x06b6;
#                                 var12 = storage[0x08] &amp; 0x02 ** 0xa0 - 0x01;
#                                 var temp29 = memory[0x40:0x60];
#                                 memory[temp29:temp29 + 0x20] = var12 &amp; 0x02 ** 0xa0 - 0x01;
#                                 var temp30 = memory[0x40:0x60];
#                                 return memory[temp30:temp30 + temp29 - temp30 + 0x20];
#                             } else if (var10 == 0x9522ca89) {
#                                 var temp31 = memory[0x40:0x60];
#                                 var12 = temp31;
#                                 var13 = 0x07;
#                                 var temp32 = storage[var13];
#                                 var temp33 = (temp32 &amp; !(temp32 &amp; 0x01) * 0x0100 + ~0x00) / 0x02;
#                                 memory[0x40:0x60] = var12 + (temp33 + 0x1f) / 0x20 * 0x20 + 0x20;
#                                 memory[var12:var12 + 0x20] = temp33;
#                                 var11 = 0x06d3;
#                                 var14 = temp33;
#                                 var15 = var12 + 0x20;
#                                 var16 = var13;
#                                 var17 = var14;
#
#                                 if (!var17) {
#                                     <a class="hljs-name" href="#func_func_076C">func_076C</a>(var13, var14, var15, var16, var17);
#                                     var temp34 = memory[0x40:0x60];
#                                     var13 = temp34;
#                                     var14 = var13;
#                                     var temp35 = var14 + 0x20;
#                                     memory[var14:var14 + 0x20] = temp35 - var14;
#                                     var temp36 = var12;
#                                     memory[temp35:temp35 + 0x20] = memory[temp36:temp36 + 0x20];
#                                     var temp37 = temp35 + 0x20;
#                                     var temp38 = memory[temp36:temp36 + 0x20];
#                                     memory[temp37:temp37 + temp38] = address(0x04).call.gas((temp38 + 0x1f) / 0x20 * 0x0f + 0x03)(memory[temp36 + 0x20:temp36 + 0x20 + temp38]);
#                                     var15 = temp38 + temp37;
#                                     var16 = temp38 &amp; 0x1f;
#
#                                     if (!var16) {
#                                         var temp39 = memory[0x40:0x60];
#                                         return memory[temp39:temp39 + var15 - temp39];
#                                     } else {
#                                         var temp40 = var16;
#                                         var temp41 = var15 - temp40;
#                                         memory[temp41:temp41 + 0x20] = ~(0x0100 ** (0x20 - temp40) - 0x01) &amp; memory[temp41:temp41 + 0x20];
#                                         var temp42 = memory[0x40:0x60];
#                                         return memory[temp42:temp42 + (temp41 + 0x20) - temp42];
#                                     }
#                                 } else if (0x1f &lt; var17) {
#                                     var temp43 = var15;
#                                     var temp44 = temp43 + var17;
#                                     var15 = temp44;
#                                     memory[0x00:0x20] = var16;
#                                     var temp45 = keccak256(memory[0x00:0x20]);
#                                     memory[temp43:temp43 + 0x20] = storage[temp45];
#                                     var16 = temp45 + 0x01;
#                                     var17 = temp43 + 0x20;
#
#                                     if (var15 &lt;= var17) { goto label_0763; }
#
#                                 label_074F:
#                                     var temp46 = var16;
#                                     var temp47 = var17;
#                                     memory[temp47:temp47 + 0x20] = storage[temp46];
#                                     var16 = temp46 + 0x01;
#                                     var17 = temp47 + 0x20;
#
#                                     if (var15 &gt; var17) { goto label_074F; }
#
#                                 label_0763:
#                                     var temp48 = var15;
#                                     var temp49 = temp48 + (var17 - temp48 &amp; 0x1f);
#                                     var17 = temp48;
#                                     var15 = temp49;
#                                     <a class="hljs-name" href="#func_func_076C">func_076C</a>(var13, var14, var15, var16, var17);
#                                     // Error: Could not resolve method call return address!
#                                 } else {
#                                     var temp50 = var15;
#                                     memory[temp50:temp50 + 0x20] = storage[var16] / 0x0100 * 0x0100;
#                                     var15 = temp50 + 0x20;
#                                     var17 = var17;
#                                     <a class="hljs-name" href="#func_func_076C">func_076C</a>(var13, var14, var15, var16, var17);
#                                     // Error: Could not resolve method call return address!
#                                 }
#                             } else if (var10 == 0x9af1d35a) {
#                                 var11 = 0x06a4;
#                                 var12 = storage[0x02];
#                                 goto label_06A4;
#                             } else if (var10 == 0xa6b165ee) {
#                                 var11 = 0x06a4;
#                                 var12 = storage[0x01];
#                                 goto label_06A4;
#                             } else if (var10 == 0xb69ef8a8) {
#                                 var11 = 0x06a4;
#                                 var12 = storage[0x03];
#                                 goto label_06A4;
#                             } else if (var10 == 0xbda393d3) {
#                                 var11 = 0x06a4;
#                                 var12 = storage[0x06];
#                                 goto label_06A4;
#                             } else if (var10 == 0xd7315d60) {
#                                 var11 = 0x06a4;
#                                 var12 = storage[0x04];
#                                 goto label_06A4;
#                             } else { goto label_00B9; }
#                         }
#                     } else {
#                         var temp51 = var9;
#                         memory[temp51:temp51 + 0x20] = temp51;
#                         var temp52 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d94:0x0db4];
#                         var temp53 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp52;
#                         var temp54 = temp53 + var10 * 0x03;
#                         storage[temp54] = var8 + storage[temp54];
#                         var8 = storage[0x04];
#                         var10 = var5;
#
#                         if (var10 &gt;= storage[temp51]) { goto label_0002; }
#
#                         var temp55 = var9;
#                         memory[temp55:temp55 + 0x20] = temp55;
#                         var temp56 = var5;
#                         var temp57 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d34:0x0d54];
#                         var temp58 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp57;
#                         var8 = storage[temp58 + temp56 * 0x03 + 0x01] / var8 * 0x02540be400;
#                         var9 = 0x00;
#                         var10 = temp56;
#
#                         if (var10 &gt;= storage[var9]) { goto label_0002; }
#
#                         var temp59 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d74:0x0d94];
#                         var temp60 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp59;
#                         storage[temp60 + var5 * 0x03] = var8;
#
#                         if (storage[0x02] == 0x00) {
#                         label_09D8:
#                             return;
#                         } else {
#                         label_09AA:
#                             var temp61 = storage[0x02];
#                             var temp62 = memory[0x40:0x60];
#                             memory[temp62:temp62 + 0x00] = address(storage[0x08] &amp; 0x02 ** 0xa0 - 0x01).call.gas(0x00).value(temp61)(memory[temp62:temp62 + 0x00]);
#                             storage[0x05] = temp61 + storage[0x05];
#                             return;
#                         }
#                     }
#                 } else {
#                     var temp63 = storage[0x00];
#                     var temp64 = temp63 + 0x01;
#                     storage[0x01] = temp64;
#                     storage[0x00] = temp64;
#                     var8 = temp64;
#                     var9 = 0x00;
#                     var11 = temp63;
#                     var10 = var8;
#
#                     if (!var11 &gt; var10) {
#                     label_09E2:
#                         var temp65 = storage[0x00];
#                         var8 = msg.sender;
#                         var9 = 0x00;
#                         var10 = temp65 + ~0x00;
#
#                         if (var10 &gt;= temp65) { goto label_0002; }
#
#                         var temp66 = var9;
#                         memory[temp66:temp66 + 0x20] = temp66;
#                         var temp67 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d34:0x0d54];
#                         var temp68 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp67;
#                         var temp69 = temp68 + var10 * 0x03;
#                         storage[temp69] = var8 | (storage[temp69] &amp; ~(0x02 ** 0xa0 - 0x01));
#                         var temp70 = storage[temp66];
#                         var8 = var3;
#                         var9 = temp66;
#                         var10 = temp70 + ~0x00;
#
#                         if (var10 &gt;= temp70) { goto label_0002; }
#
#                         var temp71 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d94:0x0db4];
#                         var temp72 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp71;
#                         storage[temp72 + var10 * 0x03] = var8;
#                         var temp73 = storage[var9];
#                         var8 = var3 / storage[0x04] * 0x02540be400;
#                         var9 = var9;
#                         var10 = temp73 + ~0x00;
#
#                         if (var10 &gt;= temp73) { goto label_0002; }
#
#                         var temp74 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d74:0x0d94];
#                         var temp75 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp74;
#                         storage[temp75 + var10 * 0x03] = var8;
#                         var temp76 = memory[0x40:0x60];
#                         memory[0x40:0x60] = temp76 + 0x40;
#                         memory[temp76:temp76 + 0x20] = 0x1b;
#                         var temp77 = temp76 + 0x20;
#                         memory[temp77:temp77 + 0x20] = 0x4e657720496e766573746f7220686173206a6f696e6564207573210000000000;
#                         var temp78 = storage[0x07];
#                         memory[var9:var9 + 0x20] = 0x07;
#                         storage[0x07] = (memory[temp77:temp77 + 0x20] &amp; ~0xff) | 0x36;
#                         var8 = 0x07;
#                         var9 = 0x0b02;
#                         var temp79 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d54:0x0d74];
#                         var temp80 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp79;
#                         var11 = temp80;
#                         var10 = var11 + ((temp78 &amp; !(temp78 &amp; 0x01) * 0x0100 + ~0x00) / 0x02 + 0x1f) / 0x20;
#                         var9 = <a class="hljs-name" href="#func_func_08EC">func_08EC</a>(var10, var11);
#                         var7 = 0x00;
#
#                         if (var7 &gt;= storage[0x00]) {
#                         label_0B76:
#
#                             if (storage[0x02] == 0x00) { goto label_09D8; }
#                             else { goto label_09AA; }
#                         } else {
#                         label_0B14:
#                             var8 = storage[0x04];
#                             var9 = 0x00;
#                             var10 = var7;
#
#                             if (var10 &gt;= storage[var9]) { goto label_0002; }
#
#                             var temp81 = var9;
#                             memory[temp81:temp81 + 0x20] = temp81;
#                             var temp82 = memory[0x00:0x20];
#                             memory[0x00:0x20] = code[0x0d94:0x0db4];
#                             var temp83 = memory[0x00:0x20];
#                             memory[0x00:0x20] = temp82;
#                             var8 = storage[temp83 + var10 * 0x03] / var8 * 0x02540be400;
#                             var10 = var7;
#
#                             if (var10 &gt;= storage[temp81]) { goto label_0002; }
#
#                             var temp84 = memory[0x00:0x20];
#                             memory[0x00:0x20] = code[0x0d74:0x0d94];
#                             var temp85 = memory[0x00:0x20];
#                             memory[0x00:0x20] = temp84;
#                             storage[temp85 + var10 * 0x03] = var8;
#                             var7 = var7 + 0x01;
#
#                             if (var7 &gt;= storage[0x00]) { goto label_0B76; }
#                             else { goto label_0B14; }
#                         }
#                     } else {
#                         var temp86 = var9;
#                         memory[temp86:temp86 + 0x20] = temp86;
#                         var temp87 = var11;
#                         var11 = 0x09e2;
#                         var temp88 = memory[0x00:0x20];
#                         memory[0x00:0x20] = code[0x0d34:0x0d54];
#                         var temp89 = memory[0x00:0x20];
#                         memory[0x00:0x20] = temp88;
#                         var12 = temp89 + temp87 * 0x03;
#                         var13 = var10 * 0x03 + temp89;
#
#                         if (var12 &lt;= var13) {
# ...
# <a class="anchor" name="0cee"></a><a class="anchor" name="0CEE"></a>	0CEE    93  SWAP4
# <a class="anchor" name="0cef"></a><a class="anchor" name="0CEF"></a>	0CEF    16  AND
# <a class="anchor" name="0cf0"></a><a class="anchor" name="0CF0"></a>	0CF0    92  SWAP3
# <a class="anchor" name="0cf1"></a><a class="anchor" name="0CF1"></a>	0CF1    90  SWAP1
# <a class="anchor" name="0cf2"></a><a class="anchor" name="0CF2"></a>	0CF2    92  SWAP3
# <a class="anchor" name="0cf3"></a><a class="anchor" name="0CF3"></a>	0CF3    04  DIV
# <a class="anchor" name="0cf4"></a><a class="anchor" name="0CF4"></a>	0CF4    91  SWAP2
# <a class="anchor" name="0cf5"></a><a class="anchor" name="0CF5"></a>	0CF5    90  SWAP1
# <a class="anchor" name="0cf6"></a><a class="anchor" name="0CF6"></a>	0CF6    91  SWAP2
# <a class="anchor" name="0cf7"></a><a class="anchor" name="0CF7"></a>	0CF7    01  ADD
# <a class="anchor" name="0cf8"></a><a class="anchor" name="0CF8"></a>	0CF8    93  SWAP4
# <a class="anchor" name="0cf9"></a><a class="anchor" name="0CF9"></a>	0CF9    90  SWAP1
# <a class="anchor" name="0cfa"></a><a class="anchor" name="0CFA"></a>	0CFA    93  SWAP4
# <a class="anchor" name="0cfb"></a><a class="anchor" name="0CFB"></a>	0CFB    04  DIV
# <a class="anchor" name="0cfc"></a><a class="anchor" name="0CFC"></a>	0CFC    83  DUP4
# <a class="anchor" name="0cfd"></a><a class="anchor" name="0CFD"></a>	0CFD    01  ADD
# <a class="anchor" name="0cfe"></a><a class="anchor" name="0CFE"></a>	0CFE    92  SWAP3
# <a class="anchor" name="0cff"></a><a class="anchor" name="0CFF"></a>	0CFF    90  SWAP1
# <a class="anchor" name="0d00"></a><a class="anchor" name="0D00"></a>	0D00    91  SWAP2
# <a class="anchor" name="0d01"></a><a class="anchor" name="0D01"></a>	0D01    60  PUSH1 0x52
# <a class="anchor" name="0d03"></a><a class="anchor" name="0D03"></a>	0D03    01  ADD
# <a class="anchor" name="0d04"></a><a class="anchor" name="0D04"></a>	0D04    5B  JUMPDEST
# <a class="anchor" name="0d05"></a><a class="anchor" name="0D05"></a>	0D05    82  DUP3
# <a class="anchor" name="0d06"></a><a class="anchor" name="0D06"></a>	0D06    81  DUP2
# <a class="anchor" name="0d07"></a><a class="anchor" name="0D07"></a>	0D07    11  GT
# <a class="anchor" name="0d08"></a><a class="anchor" name="0D08"></a>	0D08    15  ISZERO
# <a class="anchor" name="0d09"></a><a class="anchor" name="0D09"></a>	0D09    61  PUSH2 0x0d22
# <a class="anchor" name="0d0c"></a><a class="anchor" name="0D0C"></a>	0D0C    57  *JUMPI
# <span class="hljs-comment">	// Stack delta = +2</span>
# <span class="hljs-comment">	// Outputs[16]</span>
# <span class="hljs-comment">	// {</span>
# <span class="hljs-comment">	//     @0C57  memory[0x00:0x20] = code[0x0d74:0x0d94]</span>
# <span class="hljs-comment">	//     @0C5B  memory[0x00:0x20] = memory[0x00:0x20]</span>
# <span class="hljs-comment">	//     @0C60  storage[memory[0x00:0x20] + 0x03 * stack[-1]] = stack[-3]</span>
# <span class="hljs-comment">	//     @0C6A  memory[0x40:0x60] = memory[0x40:0x60] + 0x60</span>
# <span class="hljs-comment">	//     @0C6E  memory[memory[0x40:0x60]:memory[0x40:0x60] + 0x20] = 0x32</span>
# <span class="hljs-comment">	//     @0C97  memory[0x20 + memory[0x40:0x60]:0x20 + memory[0x40:0x60] + 0x20] = 0x4e6577206d616e75616c20496e766573746f7220686173206265656e20616464</span>
# <span class="hljs-comment">	//     @0CBF  memory[memory[0x40:0x60] + 0x40:memory[0x40:0x60] + 0x40 + 0x20] = 0x656420627920746865204d616e61676572210000000000000000000000000000</span>
# <span class="hljs-comment">	//     @0CC7  memory[stack[-2]:stack[-2] + 0x20] = 0x07</span>
# <span class="hljs-comment">	//     @0CCB  storage[0x07] = 0x65</span>
# <span class="hljs-comment">	//     @0CCC  stack[-3] = 0x07</span>
# <span class="hljs-comment">	//     @0CD7  memory[0x00:0x20] = code[0x0d54:0x0d74]</span>
# <span class="hljs-comment">	//     @0CDB  memory[0x00:0x20] = memory[0x00:0x20]</span>
# <span class="hljs-comment">	//     @0CFE  stack[-2] = memory[0x00:0x20] + ((storage[0x07] &amp; ~0x00 + !(storage[0x07] &amp; 0x01) * 0x0100) / 0x02 + 0x1f) / 0x20</span>
# <span class="hljs-comment">	//     @0CFF  stack[0] = memory[0x00:0x20]</span>
# <span class="hljs-comment">	//     @0D00  stack[-1] = 0x20 + memory[0x40:0x60]</span>
# <span class="hljs-comment">	//     @0D03  stack[1] = 0x52 + memory[0x40:0x60]</span>
# <span class="hljs-comment">	// }</span>
# <span class="hljs-comment">	// Block ends with conditional jump to <a href="#0d22">0x0d22</a>, if !(0x52 + memory[0x40:0x60] &gt; 0x20 + memory[0x40:0x60])</span>
# <a class="anchor" name="0d0d"></a><a class="anchor" name="0D0D"></a>label_0D0D:
# <span class="hljs-comment">	// Incoming jump from <a href="#0D0C">0x0D0C</a>, if not !(0x52 + memory[0x40:0x60] &gt; 0x20 + memory[0x40:0x60])</span>
# <span class="hljs-comment">	// Incoming jump from <a href="#0D0C">0x0D0C</a>, if not !(stack[-1] &gt; stack[-3])</span>
# <span class="hljs-comment">	// Inputs[4]</span>
# <span class="hljs-comment">	// {</span>
# <span class="hljs-comment">	//     @0D0D  stack[-3]</span>
# <span class="hljs-comment">	//     @0D0E  memory[stack[-3]:stack[-3] + 0x20]</span>
# <span class="hljs-comment">	//     @0D0F  stack[-2]</span>
# <span class="hljs-comment">	//     @0D14  stack[-1]</span>
# <span class="hljs-comment">	// }</span>
# <a class="anchor" name="0d0d"></a><a class="anchor" name="0D0D"></a>	0D0D    82  DUP3
# <a class="anchor" name="0d0e"></a><a class="anchor" name="0D0E"></a>	0D0E    51  MLOAD
# <a class="anchor" name="0d0f"></a><a class="anchor" name="0D0F"></a>	0D0F    82  DUP3
# <a class="anchor" name="0d10"></a><a class="anchor" name="0D10"></a>	0D10    60  PUSH1 0x00
# <a class="anchor" name="0d12"></a><a class="anchor" name="0D12"></a>	0D12    50  POP
# <a class="anchor" name="0d13"></a><a class="anchor" name="0D13"></a>	0D13    55  SSTORE
# <a class="anchor" name="0d14"></a><a class="anchor" name="0D14"></a>	0D14    91  SWAP2
# <a class="anchor" name="0d15"></a><a class="anchor" name="0D15"></a>	0D15    60  PUSH1 0x20
# <a class="anchor" name="0d17"></a><a class="anchor" name="0D17"></a>	0D17    01  ADD
# <a class="anchor" name="0d18"></a><a class="anchor" name="0D18"></a>	0D18    91  SWAP2
# <a class="anchor" name="0d19"></a><a class="anchor" name="0D19"></a>	0D19    90  SWAP1
# <a class="anchor" name="0d1a"></a><a class="anchor" name="0D1A"></a>	0D1A    60  PUSH1 0x01
# <a class="anchor" name="0d1c"></a><a class="anchor" name="0D1C"></a>	0D1C    01  ADD
# <a class="anchor" name="0d1d"></a><a class="anchor" name="0D1D"></a>	0D1D    90  SWAP1
# <a class="anchor" name="0d1e"></a><a class="anchor" name="0D1E"></a>	0D1E    61  PUSH2 0x0d04
# <a class="anchor" name="0d21"></a><a class="anchor" name="0D21"></a>	0D21    56  *JUMP
# <span class="hljs-comment">	// Stack delta = +0</span>
# <span class="hljs-comment">	// Outputs[4]</span>
# <span class="hljs-comment">	// {</span>
# <span class="hljs-comment">	//     @0D13  storage[stack[-2]] = memory[stack[-3]:stack[-3] + 0x20]</span>
# <span class="hljs-comment">	//     @0D18  stack[-3] = 0x20 + stack[-3]</span>
# <span class="hljs-comment">	//     @0D1D  stack[-2] = 0x01 + stack[-2]</span>
# <span class="hljs-comment">	//     @0D1D  stack[-1] = stack[-1]</span>
# <span class="hljs-comment">	// }</span>
# <span class="hljs-comment">	// Block ends with unconditional jump to <a href="#0d04">0x0d04</a></span>
# <a class="anchor" name="0d22"></a><a class="anchor" name="0D22"></a>label_0D22:
# <span class="hljs-comment">	// Incoming jump from <a href="#0D0C">0x0D0C</a>, if !(0x52 + memory[0x40:0x60] &gt; 0x20 + memory[0x40:0x60])</span>
# <span class="hljs-comment">	// Incoming jump from <a href="#0D0C">0x0D0C</a>, if !(stack[-1] &gt; stack[-3])</span>
# <span class="hljs-comment">	// Inputs[2]</span>
# <span class="hljs-comment">	// {</span>
# <span class="hljs-comment">	//     @0D27  stack[-4]</span>
# <span class="hljs-comment">	//     @0D28  stack[-3]</span>
# <span class="hljs-comment">	// }</span>
# <a class="anchor" name="0d22"></a><a class="anchor" name="0D22"></a>	0D22    5B  JUMPDEST
# <a class="anchor" name="0d23"></a><a class="anchor" name="0D23"></a>	0D23    50  POP
# <a class="anchor" name="0d24"></a><a class="anchor" name="0D24"></a>	0D24    61  PUSH2 0x0d2e
# <a class="anchor" name="0d27"></a><a class="anchor" name="0D27"></a>	0D27    92  SWAP3
# <a class="anchor" name="0d28"></a><a class="anchor" name="0D28"></a>	0D28    91  SWAP2
# <a class="anchor" name="0d29"></a><a class="anchor" name="0D29"></a>	0D29    50  POP
# <a class="anchor" name="0d2a"></a><a class="anchor" name="0D2A"></a>	0D2A    61  PUSH2 0x08ec
# <a class="anchor" name="0d2d"></a><a class="anchor" name="0D2D"></a>	0D2D    56  *JUMP
# <span class="hljs-comment">	// Stack delta = -1</span>
# <span class="hljs-comment">	// Outputs[2]</span>
# <span class="hljs-comment">	// {</span>
# <span class="hljs-comment">	//     @0D27  stack[-4] = 0x0d2e</span>
# <span class="hljs-comment">	//     @0D28  stack[-3] = stack[-4]</span>
# <span class="hljs-comment">	// }</span>
# <span class="hljs-comment">	// Block ends with call to <a href="#08ec">0x08ec</a>, returns to <a href="#0D2E">0x0D2E</a></span>
# <a class="anchor" name="0d2e"></a><a class="anchor" name="0D2E"></a>label_0D2E:
# <span class="hljs-comment">	// Incoming return from call to <a href="#08EC">0x08EC</a> at <a href="#0D2D">0x0D2D</a></span>
# <span class="hljs-comment">	// Inputs[1] { @0D33  stack[-5] }</span>
# <a class="anchor" name="0d2e"></a><a class="anchor" name="0D2E"></a>	0D2E    5B  JUMPDEST
# <a class="anchor" name="0d2f"></a><a class="anchor" name="0D2F"></a>	0D2F    50  POP
# <a class="anchor" name="0d30"></a><a class="anchor" name="0D30"></a>	0D30    50  POP
# <a class="anchor" name="0d31"></a><a class="anchor" name="0D31"></a>	0D31    50  POP
# <a class="anchor" name="0d32"></a><a class="anchor" name="0D32"></a>	0D32    50  POP
# <a class="anchor" name="0d33"></a><a class="anchor" name="0D33"></a>	0D33    56  *JUMP
# <span class="hljs-comment">	// Stack delta = -5</span>
# <span class="hljs-comment">	// Block ends with unconditional jump to stack[-5]</span>
# <a class="anchor" name="0d34"></a><a class="anchor" name="0D34"></a>	0D34    29    29
# <a class="anchor" name="0d35"></a><a class="anchor" name="0D35"></a>	0D35    0D    0D
# <a class="anchor" name="0d36"></a><a class="anchor" name="0D36"></a>	0D36    EC    EC
# <a class="anchor" name="0d37"></a><a class="anchor" name="0D37"></a>	0D37    D9    D9
# <a class="anchor" name="0d38"></a><a class="anchor" name="0D38"></a>	0D38    54    SLOAD
# <a class="anchor" name="0d39"></a><a class="anchor" name="0D39"></a>	0D39    8B    DUP12
# <a class="anchor" name="0d3a"></a><a class="anchor" name="0D3A"></a>	0D3A    62    PUSH3 0xa8d603
# <a class="anchor" name="0d3e"></a><a class="anchor" name="0D3E"></a>	0D3E    45    GASLIMIT
# <a class="anchor" name="0d3f"></a><a class="anchor" name="0D3F"></a>	0D3F    A9    A9
# <a class="anchor" name="0d40"></a><a class="anchor" name="0D40"></a>	0D40    88    DUP9
# <a class="anchor" name="0d41"></a><a class="anchor" name="0D41"></a>	0D41    38    CODESIZE
# <a class="anchor" name="0d42"></a><a class="anchor" name="0D42"></a>	0D42    6F    PUSH16 0xc84ba6bc95484008f6362f93160ef3e5
# <a class="anchor" name="0d53"></a><a class="anchor" name="0D53"></a>	0D53    63    PUSH4 0xa66cc928
# <a class="anchor" name="0d58"></a><a class="anchor" name="0D58"></a>	0D58    B5    B5
# <a class="anchor" name="0d59"></a><a class="anchor" name="0D59"></a>	0D59    ED    ED
# <a class="anchor" name="0d5a"></a><a class="anchor" name="0D5A"></a>	0D5A    B8    B8
# <a class="anchor" name="0d5b"></a><a class="anchor" name="0D5B"></a>	0D5B    2A    2A
# <a class="anchor" name="0d5c"></a><a class="anchor" name="0D5C"></a>	0D5C    F9    F9
# <a class="anchor" name="0d5d"></a><a class="anchor" name="0D5D"></a>	0D5D    BD    BD
# <a class="anchor" name="0d5e"></a><a class="anchor" name="0D5E"></a>	0D5E    49    49
# <a class="anchor" name="0d5f"></a><a class="anchor" name="0D5F"></a>	0D5F    92    SWAP3
# <a class="anchor" name="0d60"></a><a class="anchor" name="0D60"></a>	0D60    29    29
# <a class="anchor" name="0d61"></a><a class="anchor" name="0D61"></a>	0D61    54    SLOAD
# <a class="anchor" name="0d62"></a><a class="anchor" name="0D62"></a>	0D62    15    ISZERO
# <a class="anchor" name="0d63"></a><a class="anchor" name="0D63"></a>	0D63    5A    GAS
# <a class="anchor" name="0d64"></a><a class="anchor" name="0D64"></a>	0D64    B7    B7
# <a class="anchor" name="0d65"></a><a class="anchor" name="0D65"></a>	0D65    B0    PUSH
# <a class="anchor" name="0d66"></a><a class="anchor" name="0D66"></a>	0D66    94    SWAP5
# <a class="anchor" name="0d67"></a><a class="anchor" name="0D67"></a>	0D67    26    26
# <a class="anchor" name="0d68"></a><a class="anchor" name="0D68"></a>	0D68    94    SWAP5
# <a class="anchor" name="0d69"></a><a class="anchor" name="0D69"></a>	0D69    BE    BE
# <a class="anchor" name="0d6a"></a><a class="anchor" name="0D6A"></a>	0D6A    A4    LOG4
# <a class="anchor" name="0d6b"></a><a class="anchor" name="0D6B"></a>	0D6B    CE    CE
# <a class="anchor" name="0d6c"></a><a class="anchor" name="0D6C"></a>	0D6C    44    DIFFICULTY
# <a class="anchor" name="0d6d"></a><a class="anchor" name="0D6D"></a>	0D6D    66    PUSH7 0x1d9a8736c68829
# <a class="anchor" name="0d75"></a><a class="anchor" name="0D75"></a>	0D75    0D    0D
# <a class="anchor" name="0d76"></a><a class="anchor" name="0D76"></a>	0D76    EC    EC
# <a class="anchor" name="0d77"></a><a class="anchor" name="0D77"></a>	0D77    D9    D9
# <a class="anchor" name="0d78"></a><a class="anchor" name="0D78"></a>	0D78    54    SLOAD
# <a class="anchor" name="0d79"></a><a class="anchor" name="0D79"></a>	0D79    8B    DUP12
# <a class="anchor" name="0d7a"></a><a class="anchor" name="0D7A"></a>	0D7A    62    PUSH3 0xa8d603
# <a class="anchor" name="0d7e"></a><a class="anchor" name="0D7E"></a>	0D7E    45    GASLIMIT
# <a class="anchor" name="0d7f"></a><a class="anchor" name="0D7F"></a>	0D7F    A9    A9
# <a class="anchor" name="0d80"></a><a class="anchor" name="0D80"></a>	0D80    88    DUP9
# <a class="anchor" name="0d81"></a><a class="anchor" name="0D81"></a>	0D81    38    CODESIZE
# <a class="anchor" name="0d82"></a><a class="anchor" name="0D82"></a>	0D82    6F    PUSH16 0xc84ba6bc95484008f6362f93160ef3e5
# <a class="anchor" name="0d93"></a><a class="anchor" name="0D93"></a>	0D93    65    PUSH6 0x290decd9548b
# <a class="anchor" name="0d9a"></a><a class="anchor" name="0D9A"></a>	0D9A    62    PUSH3 0xa8d603
# <a class="anchor" name="0d9e"></a><a class="anchor" name="0D9E"></a>	0D9E    45    GASLIMIT
# <a class="anchor" name="0d9f"></a><a class="anchor" name="0D9F"></a>	0D9F    A9    A9
# <a class="anchor" name="0da0"></a><a class="anchor" name="0DA0"></a>	0DA0    88    DUP9
# <a class="anchor" name="0da1"></a><a class="anchor" name="0DA1"></a>	0DA1    38    CODESIZE
# <a class="anchor" name="0da2"></a><a class="anchor" name="0DA2"></a>	0DA2    6F    PUSH16 0xc84ba6bc95484008f6362f93160ef3e5
# <a class="anchor" name="0db3"></a><a class="anchor" name="0DB3"></a>	0DB3    64    PUSH5 0x
# </div> <script>
# 		$(document).ready(function() {
# 			$('.code').each(function(i, block) {
# 				hljs.highlightBlock(block);
# 			});
# 		});
# 	</script></div>
# </div>
# <div style="text-align: center; margin-top: 1em; line-height: 1; margin-bottom: 1em">
# <small>
# 				Found this site useful?<br>
# 				Donations are greatly appreciated!<br>
# 				ETH: <a href="https://etherscan.io/address/0xB3F04f0c276fa1177c1779f6E1E156B2738ea392"><tt>0xB3F04f0c276fa1177c1779f6E1E156B2738ea392</tt></a><br>
# 				Contact/hire: <a href="/cdn-cgi/l/email-protection#f09584989582869db0979d91999cde939f9d"><span class="__cf_email__" data-cfemail="7217061a1700041f32151f131b1e5c111d1f">[email protected]</span></a>
# </br></br></br></small>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="//static.ethervm.io/js/bootstrap/popper.min.js"></script>
# <script src="//static.ethervm.io/js/bootstrap/bootstrap.min.js"></script>
# <script src="//static.ethervm.io/js/clipboard/clipboard.min.js"></script>
# <script>new Clipboard(".copy-button");</script>
# </body>
# </html>
#
# None
